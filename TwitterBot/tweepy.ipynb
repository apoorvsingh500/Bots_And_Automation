# %%
import tweepy
import base64
import twitter #python-twitter
import requests
import json
from twitterscraper import query_tweets
import datetime as  dt
import pandas as pd
import time
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
from twython import Twython
import random
from TwitterAPI import TwitterAPI
from twarc import Twarc
import json
import codecs
import twitter
from twitter import *
import logging
import sys
import requests
#from keys import *
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows NT 5.2; RW; rv:7.0a1) Gecko/20091211 SeaMonkey/9.23a1pre'}

# %%
#CONSUMER AND ACCESS KEY
print('this is my twitter bot')
CONSUMER_KEY = '5EqSRBG0bagQis2R1HOJ4ab5m'
CONSUMER_SECRET = 'WMV7YiEJf8NeuNL4sl65xEXQlf3Nn92lDpLsS777PsPX3vMzWG'
ACCESS_KEY = '1261895356486279168-0oznyTqiYi1r2yaieFooj7EtKzoQlH'
ACCESS_SECRET = 'wWjphH3sk7c9BUG9VvlclGf26CLaa0WfKEf6bdJBkAPGx'
# Out:
# this is my twitter bot

# %%
t = Twitter(
    auth=OAuth(ACCESS_KEY, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET))

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)
api = tweepy.API(auth)

# %%
#api_pt = twitter.api(consumer_key=CONSUMER_KEY,
#                  consumer_secret=CONSUMER_SECRET,
#                  access_token_key=ACCESS_KEY,
#                  access_token_secret=ACCESS_SECRET)

# %%
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET,ACCESS_KEY, ACCESS_SECRET)

# %%
api

# %%
twitter
# Out:
# <Twython: 5EqSRBG0bagQis2R1HOJ4ab5m>

# %%
#MENTION TIMELINE
#api.mentions_timeline()
#mentions = api.mentions_timeline()
#type(mentions[0])
#mentions[0].__dict__.keys()

# %%
#for mention in mentions:
#    print(str(mention.id) + " - " + mention.text)
#    if('#helloworld' in mention.text.lower()):
#        print('found #helloworld')
#        print('responding back...')

# %%
# api.user_timeline(id = "editknov")
# tweepy.Cursor(api.user_timeline, id = "editknov")

# %%
#hm = api.home_timeline()
#hm[0].__dict__.keys()
#for h in hm:
#    print(h.id, h.text)

# %%
#usr = api.get_user(id='sapoorv57')
#usr.__dict__.keys()
#sts = usr.status

# %%
#consumer_key = CONSUMER_KEY
#consumer_secret_key = CONSUMER_SECRET
#Reformat the keys and encode them
#key_secret = '{}:{}'.format(consumer_key, consumer_secret_key).encode('ascii')
#Transform from bytes to bytes that can be printed
#b64_encoded_key = base64.b64encode(key_secret)
#Transform from bytes back into Unicode
#b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
#base_url = 'https://api.twitter.com/'
#auth_url = '{}oauth2/token'.format(base_url)
#auth_headers = {
#    'Authorization': 'Basic {}'.format(b64_encoded_key),
#    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
#}
#auth_data = {
#    'grant_type': 'client_credentials'
#}
#auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)
#print(auth_resp.status_code)
#access_token = auth_resp.json()['access_token']

# %%
headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok',
}
search_params = {
   'q': '#BLM',
   'lang': 'en',
   'result_type': 'mixed'
}#

search_url = 'https://api.twitter.com/1.1/search/tweets.json'  
search_resp = requests.get(search_url, headers=search_headers, params=search_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-2e2841e4ec6f> in <module>
#       9
#      10 search_url = 'https://api.twitter.com/1.1/search/tweets.json'
# ---> 11 search_resp = requests.get(search_url, headers=search_headers, params=search_params)
#
# NameError: name 'search_headers' is not defined

# %%
#type(search_resp)
#js = search_resp.json()
#type(js)
#js.keys()
#for i in js:
#    print(type(js[i]))
#js['statuses'][0]

# %%
#ALREADY HAVE DONE FROM MAY 14,20

# %%
#DATE AND LIMIT AND LANGUAGE
begin_date = dt.date(2020,4,1)
end_date = dt.date(2020,4,30)
limit = 1000
# lang = "english"
#user = editknov

# %%
#SEARCH FOR A GIVEN HASHTAGE, DATE, LANGUAGE, AND LIMIT OF TWEETS
tweets = query_tweets("#zoomlife",begindate = begin_date, enddate=end_date, limit = limit, 
                      lang = lang)
# Out:
# INFO: queries: ['#zoomlife since:2020-04-01 until:2020-04-02', '#zoomlife since:2020-04-02 until:2020-04-03', '#zoomlife since:2020-04-03 until:2020-04-05', '#zoomlife since:2020-04-05 until:2020-04-06', '#zoomlife since:2020-04-06 until:2020-04-08', '#zoomlife since:2020-04-08 until:2020-04-09', '#zoomlife since:2020-04-09 until:2020-04-11', '#zoomlife since:2020-04-11 until:2020-04-12', '#zoomlife since:2020-04-12 until:2020-04-14', '#zoomlife since:2020-04-14 until:2020-04-15', '#zoomlife since:2020-04-15 until:2020-04-16', '#zoomlife since:2020-04-16 until:2020-04-18', '#zoomlife since:2020-04-18 until:2020-04-19', '#zoomlife since:2020-04-19 until:2020-04-21', '#zoomlife since:2020-04-21 until:2020-04-22', '#zoomlife since:2020-04-22 until:2020-04-24', '#zoomlife since:2020-04-24 until:2020-04-25', '#zoomlife since:2020-04-25 until:2020-04-27', '#zoomlife since:2020-04-27 until:2020-04-28', '#zoomlife since:2020-04-28 until:2020-04-30']
# ...

# %%
#CONVERTING INTO DATAFRAME
df_tweets = pd.DataFrame(t.__dict__ for t in tweets)

# %%
df_tweets.columns
# Out:
# Index([], dtype='object')

# %%
# df_tweets.shape[0]

# %%
FILE_NAME = 'last_seen_id.txt'

def retrieve_last_seen_id(file_name):
    f_read = open(file_name, 'r')
    last_seen_id = f_read.readlines()
    f_read.close()
    return last_seen_id

# %%
def store_last_seen_id(last_seen_id, file_name):
    f_write = open(file_name, 'w')
    f_write.write(last_seen_id)
    f_write.write('\n')
    f_write.close()
    return

# %%
#REVERSED BECAUSE FIRST REPLY TO THE OLDEST TWEET AND THE TO THE NEW ONE
#def reply_to_tweets():
#    print('retrieving and replying to tweets...', flush=True)
    # DEV NOTE: use 1060651988453654528 for testing.
#    last_seen_id = retrieve_last_seen_id(FILE_NAME)
 #   for mention in reversed(mentions):
 #       print(str(mention.id) + ' - ' + mention.full_text, flush=True)
  #      last_seen_id = df_tweet.id
   #    if '#helloworld' in mention.full_text.lower():
    #        print('found #helloworld!', flush=True)
     #       print('responding back...', flush=True)
      #      api.update_status('@' + mention.user.screen_name +
       #             '#HelloWorld back to you!', mention.id)

#while True:
  #  reply_to_tweets()
    #time.sleep(15)

# %%
FILE_NAME = 'last_seen_id.txt'
def checking(tmp):
    last_seen_id = retrieve_last_seen_id(FILE_NAME)
    for ind in df_tweets.index:
        if(tmp >= 100):
            break
        found = False
        for line in last_seen_id:
            if df_tweets['user_id'][ind] == line.strip():
                found = True
                print('found existing id....')
                break
        if found == False:
            store_last_seen_id(df_tweets['user_id'][ind], FILE_NAME)
            if(sentiment_analyzer_scores(df_tweets['text'][ind])>=0.3):
                #like(df_tweets['tweet_id'][ind])
                print(tmp)
                tmp +=1                
                cmt('a','b')
                #time.sleep(random.randint(1,4))
                #comment(df_tweets['tweet_id'][ind], df_tweets['screen_name'][ind])
                #share(df_tweets['tweet_id'][ind])
# x = 0       
# checking(x)

# %%
Dict = {}
Dict[1] = 'Lock-down is a strange time but we are coming out strong. Take a moment to check out about us and spread the word if it is helpful. Link- https://bit.ly/zoomersin #zoom #partyherd'
Dict[2] = 'Lockdown has affected us all in different capacity but we are coming out strong. Take a moment to check out about us and spread the word if it is helpful. Link- https://bit.ly/zoomersin #zoom #partyherd'
Dict[3] = 'Good stuff. Check out this community of #zoomers in India bit.ly/zoomersin #zoom #partyherd'

# %%
# def cmt(idd,name):
#     x= random.randint(1,15)
#     print(Dict[x])

# %%
#LIKE CORRECT
def like(idd):
    api.create_favorite (id = idd)

# %%
#COMMENT CORRECT
def comment(idd):
    x= random.randint(1,3)
    tweetex=api.update_status(Dict[x],auto_populate_reply_metadata = True
                          ,in_reply_to_status_id = idd)

# %%
#SHARE CORRECT
def share(idd):
    api.retweet(id = idd)

# %%
#FOLLOW CORRECT(dont use)
#def follow(idd, name):
#    api.create_friendship(id = idd, screen_name = name)

# %%
#DM
#def DM(idd):
#    api.send_direct_message(recipient_id=idd, text="Yo")

# %%
#SENTIMENT ANALYZER SCORES
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    #print(score['compound'])
    return score['compound']

# %%
#USERID USING USERNAME
user = api.get_user(screen_name = 'chhavisawhney')
user.id
# Out:
# 1102568275

# %%
#USERNAME USING USERID
u = api.get_user(1040519558442868738)
print (u.screen_name)
# Out:
# sirfcliche

# %%
#CHECK A PARTICULAR USERS POSTS
stuff = api.user_timeline(screen_name = 'Bhuvan_Bam', count = 200, include_rts = True)

# %%
print(stuff[28].text,stuff[28].id)
# Out:
# My second channel now streams joke writing sessions, screenwriting sessions. First screenwriting session @satysingh… https://t.co/MPPALsKkiG 1263214352980533248

# %%
score = analyser.polarity_scores(stuff[4].text)
print(score['compound'])
# Out:
# 0.6239

# %%
print(type(str(stuff[1]._json['user']['id'])))
# Out:
# <class 'str'>

# %%
CONSUMER_KEY = '5EqSRBG0bagQis2R1HOJ4ab5m'
CONSUMER_SECRET = 'WMV7YiEJf8NeuNL4sl65xEXQlf3Nn92lDpLsS777PsPX3vMzWG'
ACCESS_KEY = '1261895356486279168-0oznyTqiYi1r2yaieFooj7EtKzoQlH'
ACCESS_SECRET = 'wWjphH3sk7c9BUG9VvlclGf26CLaa0WfKEf6bdJBkAPGx'

# %%
api_tapi = TwitterAPI(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)

# %%
# Out:
# {"created_at":"Wed Jun 06 20:07:10 +0000 2012","id":210462857140252672,"id_str":"210462857140252672","text":"Along with our new #Twitterbird, we've also updated our Display Guidelines: https:\/\/t.co\/Ed4omjYs  ^JC","truncated":false,"entities":{"hashtags":[{"text":"Twitterbird","indices":[19,31]}],"symbols":[],"user_mentions":[],"urls":[{"url":"https:\/\/t.co\/Ed4omjYs","expanded_url":"https:\/\/dev.twitter.com\/terms\/display-guidelines","display_url":"dev.twitter.com\/terms\/display-\u2026","indices":[76,97]}]},"source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":6253282,"id_str":"6253282","name":"Twitter API","screen_name":"TwitterAPI","location":"San Francisco, CA","description":"The Real Twitter API. Tweets about API changes, service issues and our Developer Platfor
# ...

# %%
t= Twarc(consumer_key = CONSUMER_KEY, consumer_secret = CONSUMER_SECRET, access_token = ACCESS_KEY, access_token_secret = ACCESS_SECRET)

# %%
t

# %%
# Create a summary of a tweet, only showing relevant fields.
#def summarize(tweet, extra_fields = None):
#    new_tweet = {}
#    for field, value in tweet.items():
#        if field in ["text", "id_str", "screen_name", "retweet_count", "favorite_count", "in_reply_to_status_id_str", "in_reply_to_screen_name", "in_reply_to_user_id_str"] and value is not None:
#            new_tweet[field] = value
#        elif extra_fields and field in extra_fields:
#            new_tweet[field] = value
#        elif field in ["retweeted_status", "quoted_status", "user"]:
#            new_tweet[field] = summarize(value)
#    return new_tweet

# Print out a tweet, with optional colorizing of selected fields.
#def dump(tweet, colorize_fields=None, summarize_tweet=True):
#    colorize_field_strings = []
#    for line in json.dumps(summarize(tweet) if summarize_tweet else tweet, indent=4, sort_keys=True).splitlines():
#        colorize = False
#        for colorize_field in colorize_fields or []:
#            if "\"{}\":".format(colorize_field) in line:       
#                print ("\x1b[31m" + line + "\x1b[0m")
#                break
#        else:
#            print (line)

# %%
# Retrieve a single tweet from the Twitter API
#tweet = list(t.hydrate(['1263214352980533248']))[0]
# Pretty-print the tweet
#dump(tweet, summarize_tweet=False)

# %%
#dump(tweet)

# %%
# tweet = list(t.hydrate(['1263214352980533248']))[0]
# dump(tweet, colorize_fields=['retweet_count'])

# %%
# tweet = list(t.hydrate(['1263214352980533248']))[0]
# dump(tweet, colorize_fields=['retweeted_status', 'retweet_count'])

# %%
found_retweet = False
found_quote = False
found_reply = False
found_favorited = False
found_retweeted = False
for tweet in t.timeline(screen_name='Bhuvan_Bam'):
    if 'retweeted_status' in tweet:
        print ("{} is a retweet.".format(tweet['id_str']))
        found_retweet = True
    if 'quoted_status' in tweet:
        print ("{} is a quote.".format(tweet['id_str']))
        found_quote = True
    if tweet['in_reply_to_status_id']:
        print ("{} is a reply to {} by {}".format(tweet['id_str'], tweet['in_reply_to_status_id_str'], tweet['in_reply_to_screen_name']))
        found_reply = True
    if tweet['retweet_count'] > 0:
        print ("{} has been retweeted {} times.".format(tweet['id_str'], tweet['retweet_count']))
        found_retweeted = True
    if tweet['favorite_count'] > 0:
        print ("{} has been favorited {} times.".format(tweet['id_str'], tweet['favorite_count']))
        found_favorited = True
print ("Found retweet: {}".format(found_retweet))
print ("Found quote: {}".format(found_quote))
print ("Found reply: {}".format(found_reply))
print ("Found favorited: {}".format(found_favorited))
print ("Found retweeted: {}".format(found_retweeted))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/envs/my_env/lib/python3.7/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     340         try:
# --> 341             handle = urllib_request.urlopen(req, **kwargs)
#     342             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# ~/anaconda3/envs/my_env/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~/anaconda3/envs/my_env/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ...

# %%
#GETS TEXT OF TWEET USING TWEETID
id_of_tweet = '1263466303454502913'
tweet1 = api.get_status(id_of_tweet)
print(tweet1.text)
# Out:
# RT @satysingh: Last night @thetanmay and I went live on Youtube and with the help of 2000 people watching us, we created characters for a m…

# %%
# tweet = list(t.hydrate(['1262491343168790528']))[0]
# print ("The retweet count is {}".format(tweet['retweet_count']))
# retweets = t.retweets('1262491343168790528')
# print ("Retrieved {} retweets".format(len(list(retweets))))

# %%
# print()

# %%
#curl -u '5EqSRBG0bagQis2R1HOJ4ab5m:WMV7YiEJf8NeuNL4sl65xEXQlf3Nn92lDpLsS777PsPX3vMzWG' \
#  --data 'grant_type=client_credentials' \
#  'https://api.twitter.com/oauth2/token'

# %%
#r = requests.get('https://api.twitter.com/1.1/statuses/retweeters/ids.json?id=327473909412814850&count=100&stringify_ids=true'
#,params = payload)

# %%
#AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok

# %%
payload = {'Authorization':'Bearer',  '':'AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok'}

# %%
import requests
#GET statuses/retweeters/ids
#Returns a collection of the 100 most recent retweets of the Tweet specified by the id parameter.
headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok',
}

params = (
    ('id', '1266037504416845826'),
    ('stringify_ids', 'true'),
)

response = requests.get('https://api.twitter.com/1.1/statuses/retweeters/ids.json', headers=headers, params=params)

# %%
with open('outputfile.json', 'wb') as outf:
    outf.write(response.content)

# %%
f = open('outputfilewithoutc.json',) 
data = json.load(f) 
for dt in data['ids']:
    print(dt)
# Out:
# 1040519558442868738
# 1079819409986793473

# %%
#USERNAME USING USERID
u = api.get_user(16986096)
print (u.screen_name)
# Out:
# SubhasisHazra

# %%
import requests
#GET statuses/retweets/:id
#Returns a collection of the 100 most recent retweets of the Tweet specified by the id parameter.

headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok',
}

params = (
    ('id', '1266037504416845826'),
    ('stringify_ids', 'true')
)

response = requests.get('https://api.twitter.com/1.1/statuses/retweets/1266037504416845826.json', headers=headers, params=params)
with open('outputfilewithc.json', 'wb') as outf:
    outf.write(response.content)

# %%
response.text
# Out:
# '[{"created_at":"Thu May 28 16:12:24 +0000 2020","id":1266039630584926209,"id_str":"1266039630584926209","text":"RT @thetanmay: IT\'S SOME GLITCH THAT REFUSES TO GOOOOO UGHHH","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"thetanmay","name":"Tanmay Bhat","id":14120922,"id_str":"14120922","indices":[3,13]}],"urls":[]},"source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":999126563818946561,"id_str":"999126563818946561","name":"Debashish Hazra","screen_name":"DebashishHazra3","location":"Kolkata, India","description":"","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":2,"friends_count":65,"listed_count":0,"created_at":"Wed May 23 03:15:10 +0000 2018","favourites_c
# ...

# %%
import requests
#GGET statuses/show/:id
#Returns a single Tweet, specified by the id parameter. The Tweet's author will also be embedded within the Tweet.
idd = "1270649571392106497"

headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok',
}

params = (
    ('id', idd),
    ('stringify_ids', 'true')
)
str1 = "https://api.twitter.com/1.1/statuses/show.json?id=" + idd
response = requests.get(str1, headers=headers, params=params)
#response = requests.get('https://api.twitter.com/1.1/statuses/show.json?id=1266037504416845826', headers=headers, params=params)
print('https://api.twitter.com/1.1/statuses/show.json?id=1263214352980533248')
with open('outputfilewithc.json', 'wb') as outf:
    outf.write(response.content)
# Out:
# https://api.twitter.com/1.1/statuses/show.json?id=1263214352980533248

# %%
response.text
# Out:
# '{"created_at":"Thu May 28 16:03:57 +0000 2020","id":1266037504416845826,"id_str":"1266037504416845826","text":"IT\'S SOME GLITCH THAT REFUSES TO GOOOOO UGHHH https:\\/\\/t.co\\/MKNXXxuJVv","truncated":false,"entities":{"hashtags":[],"symbols":[],"user_mentions":[],"urls":[{"url":"https:\\/\\/t.co\\/MKNXXxuJVv","expanded_url":"https:\\/\\/twitter.com\\/subhasishazra\\/status\\/1266034029934964737","display_url":"twitter.com\\/subhasishazra\\/\\u2026","indices":[46,69]}]},"source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":14120922,"id_str":"14120922","name":"Tanmay Bhat","screen_name":"thetanmay","location":"Mumbai, India","description":"Writer, Comedian, Entrepreneur. Co-Founder All India Bakchod.","url":"https:\\/\\/t.co\\/n0KCgvvEMy","en
# ...

# %%
#RETWEETSWITHCOMMENTS
#IMPORTANT
import requests
#idd = str(stuff[4].id)
idd = "1267833596858920960"
#https://dev.twitter.com/rest/reference/get/search/tweets
headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok',
}

params = (
    ('id', idd),
    ('stringify_ids', 'true')
)
str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=600&until=2020-06-03'
#str2 = 'https://api.twitter.com/1.1/statuses/retweeters/ids.json?id=1267833596858920960&count=100&stringify_ids=true'
#print(str1)
#max_id=1268053517480198143&q=1267833596858920960&count=100&include_entities=1
response = requests.get(str1,headers=headers, params=params)
#response = requests.get('https://api.twitter.com/1.1/search/tweets.json?q=1266037504416845826&count=100', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.twitter.com/1.1/statuses/retweeters/ids.json?id=327473909412814850&count=100&stringify_ids=true', headers=headers)
with open('outputfilewithc.json', 'wb') as outf:
    outf.write(response.content)

# %%
# #print(stuff[0].text)
# #print(stuff[0].id)

# print(response.text)

# %%
#with open('outputfilewithoutc.json', 'wb') as outf:
    #outf.write(response.content)
with open('outputfilewithc.json', 'wb') as outf:
    outf.write(response.content)

# %%
# import json   
# f = open('outputfilewithc.json',) 
# data = json.load(f)
# for dt in data['statuses']:
#     x = dt['user']['id_str']
#     u = api.get_user(x)
#     print (u.screen_name)
# #data['statuses'][0]['user']['id_str']
# #data['statuses'][0]['id_str']

# %%
# import json   
# f = open('outputfilewithc.json',) 
# data = json.load(f)
# for dt in data['statuses']:
#     x = dt['user']['id_str']
#     u = api.get_user(x)
#     print (u.screen_name)
# #data['statuses'][0]['user']['id_str']
# #data['statuses'][0]['id_str']

# %%
# for x in data['statuses']:
#     print(x['id_str'])

# %%
# for st in stuff:
#     print(str(st.id))

# %%
# len(stuff)
def get_tweets(query, count = 300):

    # empty list to store parsed tweets
    tweets = []
    target = io.open("mytweets.txt", 'w', encoding='utf-8')
    # call twitter api to fetch tweets
    q=str(query)
    a=str(q+" sarcasm")
    b=str(q+" sarcastic")
    c=str(q+" irony")
    fetched_tweets = api.search(a, count = count)+ api.search(b, count = count)+ api.search(c, count = count)
    # parsing tweets one by one
    print(len(fetched_tweets))

    for tweet in fetched_tweets:

        # empty dictionary to store required params of a tweet
        parsed_tweet = {}
        # saving text of tweet
        parsed_tweet['text'] = tweet.text
        if "http" not in tweet.text:
            line = re.sub("[^A-Za-z]", " ", tweet.text)
            target.write(line+"\n")
    return tweets

    # creating object of TwitterClient Class
    # calling function to get tweets
tweets = get_tweets(query ="", count = 20000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d0af836b7dd3> in <module>
#      27     # creating object of TwitterClient Class
#      28     # calling function to get tweets
# ---> 29 tweets = get_tweets(query ="", count = 20000)
#
# <ipython-input-30-d0af836b7dd3> in get_tweets(query, count)
#       4     # empty list to store parsed tweets
#       5     tweets = []
# ----> 6     target = io.open("mytweets.txt", 'w', encoding='utf-8')
#       7     # call twitter api to fetch tweets
#       8     q=str(query)
#
# NameError: name 'io' is not defined

# %%
####CODE 2
#STEP 1 GET SCREENNAME AND ID
name = 'thetanmay'
#STEP 2 GET ALLL HIS RECENT TWEETS
stuff = api.user_timeline(screen_name = 'thetanmay', count = 10, include_rts = True)
idd = str(stuff[1]._json['user']['id'])
last_seen_id = retrieve_last_seen_id(FILE_NAME)
tmp = 0
for st in stuff:    #STEP ---> STORE THE USERIDS OF THESE RETWEETS
        
    #STEP 3 GET ALL THE RETWEETS WITH COMMENTS
    idd = str(st.id)
    #idd = "1266074445585674240"
    #https://dev.twitter.com/rest/reference/get/search/tweets
    headers = {
        'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok',
    }

    params = (
        ('id', idd),
        ('stringify_ids', 'true')
    )
    str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=100'
    #print(str1)
    response = requests.get(str1,headers=headers, params=params)
    #response = requests.get('https://api.twitter.com/1.1/search/tweets.json?q=1266037504416845826&count=100', headers=headers, params=params)

    #STEP 4 LIKE FOLLOW AND COMMENT ON THE STATUS
    with open('outputfilewithc.json', 'wb') as outf:
        outf.write(response.content)
    f = open('outputfilewithc.json',) 
    data = json.load(f)
    for dt in data['statuses']:
        if(tmp >= 20):
            break
        found = False
        for line in last_seen_id:
            if dt['id_str'] == line.strip():
                found = True
                print('found existing id....')
                break
        if found == False:
            store_last_seen_id(dt['id_str'], FILE_NAME)
            try:
                tmpidd = dt['id_str']
                print("not found")
                like(tmpidd)
                comment(tmpidd)
                tmp+=1
            except:
                print("error")
                continue

# %%
# Function the pulls tweets from a specific username and turns to csv file

# Parameters: (list of twitter usernames), (max number of most recent tweets to pull from)
def username_tweets_to_csv(username, count):
    # Creation of query object
    tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                                            .setMaxTweets(count)
    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)

    # Creating list of chosen tweet data
    user_tweets = [[tweet.date, tweet.text] for tweet in tweets]

    # Creation of dataframe from tweets list
    tweets_df = pd.DataFrame(user_tweets, columns = ['Datetime', 'Text'])

    # Converting dataframe to CSV
    tweets_df.to_csv('{}-{}k-tweets.csv'.format(username, int(count/1000)), sep=',')
    return tweets_df

# %%
# Function that pulls tweets based on a general search query and turns to csv file

# Parameters: (text query you want to search), (max number of most recent tweets to pull from)
def text_query_to_csv(count):
    # Creation of query object
    tweetCriteria = got.manager.TweetCriteria().setMaxTweets(count).setNear('Mumbai').setWithin('150km')
    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)

    # Creating list of chosen tweet data
    text_tweets = [[tweet.id, tweet.text,tweet.username,tweet.to,tweet.geo] for tweet in tweets]

    # Creation of dataframe from tweets
    tweets_df = pd.DataFrame(text_tweets, columns = ['id', 'Text','Username','To','Geolocation'])

    # Converting tweets dataframe to csv file
    #tweets_df.to_csv('{}-{}k-tweets.csv'.format(text_query, int(count/1000)), sep=',')
    return tweets_df

# %%
# Input username(s) to scrape tweets and name csv file
# Max recent tweets pulls x amount of most recent tweets from that user
#username = 'CarryMinati'
count = 1000

# Calling function to turn username's past x amount of tweets into a CSV file
#df = username_tweets_to_csv(username, count)
df = text_query_to_csv(1000)

# %%
df[:]
# Out:
#                       id                                               Text  \
# 0    1270680033112150016  I just don’t think he was all that personally....
# 1    1270680032256671745  @KapilSharmaK9 Please help me Please Help me P...
# 2    1270680032000700416                                       तेजस्वी यादव
# 3    1270680031946104832                            "गो-वध" नहीं "गो-रक्षा"
# 4    1270680030486474752  पैठणीशी संबंधित अन्य उत्पादनेही बंद... #Corona...
# ..                   ...                                                ...
# 995  1270678557585362944                          Yes!! Its bulbul tarang!
# 996  1270678552434835462
# 997  1270678551361024001                                       @sindhiboy17
# 998  1270678549989490688  Wouldn’t take it away from you, completely und...
# 999  1270678548571881473  न्यूजीलैंड कोरोना मुक्त हो गया भारत सरकार अपनी...
#
#             Username             To Geolocation
# 0       NeeljiTweets    unitedaryan
# ...

# %%
for idx in df.index:
    #print (df['id'][idx])
    idd = df['id'][idx]
#     idd = "1270649571392106497"

    headers = {
    'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAF7eEQEAAAAAvCkROSDTq%2B1ggHcuniPlf6bnLco%3DMDWR38LjeaI3smcOErA5FdFoGyopgp1s2U8TC1i0bxmp7wL8ok',
    }

    params = (
    ('id', idd),
    ('stringify_ids', 'true')
    )
    str1 = "https://api.twitter.com/1.1/statuses/show.json?id=" + idd
    response = requests.get(str1,headers=headers, params=params)
    with open('outputfilewithc.json', 'wb') as outf:
        outf.write(response.content)
    f = open('outputfilewithc.json',) 
    data = json.load(f)
    try:
        print(data['user']['location'])
    except:
        print("error")
        print(data)
# Out:
# Navi Mumbai, India
# Maharashtra, India
# Mumbai, India
# Mumbai
# Mumbai
# Mumbai, India
# Mumbai, India
# Mumbai
# Mumbai
# Pune, India
# Pune, India
# Mumbai, India
# MUMBAI
# Mumbai , India
# BOMBAY
# Mumbai
# Mumbai, India
# dapur
# Mumbai, India
# Mumbai
# Mumbai
# Prabhadevi
# Mumbai
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai
# مومباي
# Mumbai, India
# Mumbai, India
# Dombivali
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Navi Mumbai, India
# Mumbai, India
# Panvel, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# मुंबई, भारत
# Versova, Mumbai
# THANE, MAHARASHTRA
# Mumbai, India
# Mumbai, India
# mumbai india
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Wadala, Mumbai
# مومباي
# Mumbai
# Mumbai
# Mumbai
# Mumbai, India
# Mumbai, India
# Mumbai, India
# Mumbai
# Mumbai, India
# Mumbai, India
# Mumbai, India
# ...

# %%
data
# Out:
# {'errors': [{'code': 34, 'message': 'Sorry, that page does not exist.'}]}
