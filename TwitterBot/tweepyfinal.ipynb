# %%
#REQUIRED LIBRARIES
import tweepy
import base64
import twitter #python-twitter
import requests
import json
from twitterscraper import query_tweets
import datetime as  dt
import pandas as pd
import time
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
from twython import Twython
import random
from TwitterAPI import TwitterAPI
from twarc import Twarc
import json
import codecs
import twitter
from twitter import *
import logging
import sys
import requests
#from keys import *
# Out:
# INFO: {'User-Agent': 'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16'}

# %%
# APP1 CONSUMER AND ACCESS KEY
#print('this is my twitter bot')
CONSUMER_KEY = '5EqSRBG0bagQis2R1HOJ4ab5m'
CONSUMER_SECRET = 'WMV7YiEJf8NeuNL4sl65xEXQlf3Nn92lDpLsS777PsPX3vMzWG'
ACCESS_KEY = '1261895356486279168-0oznyTqiYi1r2yaieFooj7EtKzoQlH'
ACCESS_SECRET = 'wWjphH3sk7c9BUG9VvlclGf26CLaa0WfKEf6bdJBkAPGx'



#APP2 CONSUMER AND ACCESS KEY
CONSUMER_KEY1 = 'MfUUpkzkJO2ilsZDkDzJsqzhx'
CONSUMER_SECRET1 = 'pE0zzmyzjhxdW394Ks7QmnvJFXT7P0KKUZoDIcAVyLEL7INXBt'
ACCESS_KEY1 = '1261895356486279168-XrwhgOZahXHNkWPaHvEmfpEXsh9mYX'
ACCESS_SECRET1 = 'dVWEKCvpwf0TFhgqIZxmXTg40xqTWASfmIYgMAPisF9TC'

# %%
t = Twitter(auth=OAuth(ACCESS_KEY, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET))
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)
api = tweepy.API(auth)
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET,ACCESS_KEY, ACCESS_SECRET)
api_tapi = TwitterAPI(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
tt= Twarc(consumer_key = CONSUMER_KEY, consumer_secret = CONSUMER_SECRET, 
         access_token = ACCESS_KEY, access_token_secret = ACCESS_SECRET)

# %%
###APP2
t1 = Twitter(auth=OAuth(ACCESS_KEY1, ACCESS_SECRET1, CONSUMER_KEY1, CONSUMER_SECRET1))
auth1 = tweepy.OAuthHandler(CONSUMER_KEY1, CONSUMER_SECRET1)
auth1.set_access_token(ACCESS_KEY1, ACCESS_SECRET1)
api1 = tweepy.API(auth)
twitter1 = Twython(CONSUMER_KEY1, CONSUMER_SECRET1,ACCESS_KEY1, ACCESS_SECRET1)
api_tapi1 = TwitterAPI(CONSUMER_KEY1, CONSUMER_SECRET1, ACCESS_KEY1, ACCESS_SECRET1)
tt1= Twarc(consumer_key = CONSUMER_KEY1, consumer_secret = CONSUMER_SECRET1, 
         access_token = ACCESS_KEY1, access_token_secret = ACCESS_SECRET1)

# %%
# #DATE AND LIMIT AND LANGUAGE
# begin_date = dt.date(2020,4,1)
# end_date = dt.date(2020,4,30)
# limit = 1000
# lang = "english"
# hashtag = "#zoomlife"
# #user = editknov

# %%
# def gettweets(begin_date,end_date,limit,lang,hashtag):
#     tweets = query_tweets(hashtag,begindate = begin_date, enddate=end_date, limit = limit, 
#                       lang = lang)
#     df_tweets = pd.DataFrame(t.__dict__ for t in tweets)
#     return df_tweets
# df_tweets = gettweets(begin_date,end_date,limit,lang,hashtag)

# %%
Dict = {}
Dict[1] = 'Lock-down is a strange time but we are coming out strong. Take a moment to check out about us and spread the word if it is helpful. Link- https://bit.ly/2XnI0og #zoom #partyherd #millennials'
Dict[2] = 'Lockdown has affected us all in different capacity but we are coming out strong. Take a moment to check out about us and spread the word if it is helpful. Link- https://bit.ly/zoomersin #zoom #partyherd #millennials'
Dict[3] = 'Good stuff. Check out this community of #zoomers in India https://bit.ly/2XnI0og #zoom #partyherd #millennials'
Dict[4] = 'Lockdown has many unknown mental effects. Don’t lose the social touch with people. Join the community now: https://bit.ly/2XnI0og #zoom #partyherd #millennials'
Dict[5] = 'Lockdown might have brought us the human race closer than ever. Join the community of millennials on zoom: https://bit.ly/2XnI0og #zoom #partyherd #millennials'

# %%
#REQUIRED FUNCTIONS
def like(idd):
    api.create_favorite (id = idd)
def comment(idd):
    x= random.randint(1,5)
    tweetex=api.update_status(Dict[x],auto_populate_reply_metadata = True
                          ,in_reply_to_status_id = idd)
def share(idd):
    api.retweet(id = idd)
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score['compound']

# %%
FILE_NAME = 'last_seen_id.txt'
NAME = 'names.txt'
def retrieve_last_seen_id(file_name):
    f_read = open(file_name, 'r')
    last_seen_id = f_read.readlines()
    f_read.close()
    return last_seen_id

def store_last_seen_id(last_seen_id, file_name):
    f_write = open(file_name, 'a')
    f_write.write(last_seen_id)
    f_write.write('\n')
    f_write.close()
    return

# %%
# def func1(tmp):
#     last_seen_id = retrieve_last_seen_id(FILE_NAME)
#     for ind in df_tweets.index:
#         if(tmp >= 50):
#             break
#         found = False
#         for line in last_seen_id:
#             if df_tweets['user_id'][ind] == line.strip():
#                 found = True
#                 print('found existing id....')
#                 break
#         if found == False:
#             store_last_seen_id(df_tweets['user_id'][ind], FILE_NAME)
#             if(sentiment_analyzer_scores(df_tweets['text'][ind])>=0.3):
#                 try:
#                     like(df_tweets['tweet_id'][ind])
#                     print(tmp)
#                     tmp +=1                
#                 #cmt('a','b')
#                     comment(df_tweets['tweet_id'][ind])
#                     time.sleep(random.randint(40,60))
#                 except:
#                     print("error")
#                     continue
#                 #comment(df_tweets['tweet_id'][ind], df_tweets['screen_name'][ind])
#                 #share(df_tweets['tweet_id'][ind])

# %%
def func2(tmp):
    names = retrieve_last_seen_id(NAME)
    last_seen_id = retrieve_last_seen_id(FILE_NAME)
    for namestr in names:
        comedian = namestr.strip()
        print("name --------------" + comedian)
        y = 1
        for i in range(2):
            sss = str(i+1)
            print("new page")
            headers = {
            'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
            }
            str1 = "https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=" + comedian + "&count=200&page=" + str(sss)
            response = requests.get(str1,headers=headers)
            with open('ids.json', 'wb') as outf:
                outf.write(response.content)
            ff = open('ids.json') 
            data1 = json.load(ff)
            for x in data1:    
                idd = str(x['id_str'])
                print("tweet" + str(y))
                y+=1
                headers = {
                'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
                }
                params = (
                    ('id', idd),
                    ('stringify_ids', 'true')
                )
                str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=100'
                response = requests.get(str1,headers=headers, params=params)
                with open('outputfilewithc.json', 'wb') as outf:
                    outf.write(response.content)
                f = open('outputfilewithc.json') 
                data = json.load(f)
                for dt in data['statuses']:
                    if(tmp >= limit):
                        break
                    found = False
                    if(dt['is_quote_status']==False):
                        continue
                    else:
                        for line in last_seen_id:
                            if dt['user']['id_str'] == line.strip():
                                found = True
                                print('found existing id....')
                                break
                        if found == False:
                            try:
                                tmpidd = dt['id_str']
                                like(tmpidd)
                                comment(tmpidd)                    
                                tmp+=1
                                print(tmp)
                                store_last_seen_id(dt['user']['id_str'], FILE_NAME)
                                print("not found")
                                time.sleep(random.randint(40,60))
                            except:
                                print("error")
                                continue

# %%
limit = 1000
tmp = 0
err = 0
errlimit = 500
#func1(tmp)
func2(tmp)
# Out:
# name --------------be_a_bassi
# new page
# tweet1
# tweet2
# tweet3
# 1
# not found
# tweet4
# tweet5
# 2
# not found
# 3
# not found
# tweet6
# tweet7
# 4
# not found
# tweet8
# tweet9
# tweet10
# tweet11
# 5
# not found
# tweet12
# tweet13
# tweet14
# tweet15
# tweet16
# 6
# not found
# tweet17
# tweet18
# tweet19
# tweet20
# tweet21
# tweet22
# tweet23
# tweet24
# tweet25
# tweet26
# tweet27
# tweet28
# tweet29
# tweet30
# tweet31
# tweet32
# tweet33
# tweet34
# tweet35
# tweet36
# tweet37
# tweet38
# tweet39
# tweet40
# tweet41
# tweet42
# tweet43
# tweet44
# tweet45
# tweet46
# tweet47
# tweet48
# tweet49
# tweet50
# tweet51
# tweet52
# tweet53
# tweet54
# tweet55
# tweet56
# tweet57
# tweet58
# tweet59
# tweet60
# tweet61
# tweet62
# tweet63
# tweet64
# tweet65
# tweet66
# tweet67
# tweet68
# tweet69
# tweet70
# tweet71
# tweet72
# tweet73
# tweet74
# tweet75
# tweet76
# tweet77
# tweet78
# tweet79
# tweet80
# tweet81
# tweet82
# tweet83
# tweet84
# tweet85
# tweet86
# tweet87
# ...

# %%
# EXTRA FUNCTIONSSS

stuff = api.user_timeline(screen_name = 'CarryMinati', count = 200, include_rts = True)
#for st in stuff:    
    #print(s)
    
# USERNAME USING USERID

# u = api1.get_user(1241496041704153088)
# print (u.screen_name)

# #GETS TEXT OF TWEET USING TWEETID
id_of_tweet = '1269925684669042689'
tweet1 = api.get_status(id_of_tweet)
print(tweet1.text)

# #GETS TEXT OF TWEET USING TWEETID
# id_of_tweet = '1266107074888339456'
# tweet1 = api.get_status(id_of_tweet)
# print(tweet1.text)
# Out:
# WTF 😶 https://t.co/YDFuappARo

# %%
####CHECKING
#name = 'Bhuvan_Bam'
#stuff = api1.user_timeline(screen_name = name, count = 200, include_rts = True)
stuff[0].id
# Out:
# 1269939789945540608

# %%
# headers = {
#             'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
#             }
# params = (
#                 ('id', idd),
#                 ('stringify_ids', 'true')
#             )
# str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=100' + '&page=2'
# response = requests.get(str1,headers=headers, params=params)

# %%
# #st = stuff[7]
# #idd = str(st.id)
# headers = {
#             'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
#         }
# # params = (
# #             ('id', idd),
# #             ('stringify_ids', 'true')
# #         )
# #str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=100'
# str1 = "https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=Bhuvan_Bam&count=200&page=" + str(pg)
# response = requests.get(str1,headers=headers)
# with open('outputfilewithc.json', 'wb') as outf:
#     outf.write(response.content)
# f = open('outputfilewithc.json',) 
# #data = json.load(f)
# #for dt in data['statuses']:
# #    print(dt['is_quote_status'],dt['user']['id_str'])

# %%
data = json.load(f)

# %%
len(data)
# Out:
# 200

# %%
headers = {
            'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
            }
params = (
                ('id', idd),
                ('stringify_ids', 'true')
            )
str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=100' + '&page=1'
response = requests.get(str1,headers=headers, params=params)

# %%
def func2(name,limit,tmp,errlimit):
#    stuff = api.user_timeline(screen_name = name, count = 500, include_rts = True)
    last_seen_id = retrieve_last_seen_id(FILE_NAME)
    y = 1
    for i in range(2):
        sss = str(2)
        print("new page")
        headers = {
            'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
        }
        str1 = "https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=Bhuvan_Bam&count=200&page=" + str(sss)
        response = requests.get(str1,headers=headers)
        with open('ids.json', 'wb') as outf:
            outf.write(response.content)
        ff = open('ids.json') 
        data1 = json.load(ff)
        for x in data1:    
            idd = str(x['id_str'])
            print("tweet" + str(y))
            y+=1
            headers = {
            'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
            }
            params = (
                ('id', idd),
                ('stringify_ids', 'true')
            )
            str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=100'
            response = requests.get(str1,headers=headers, params=params)
            with open('outputfilewithc.json', 'wb') as outf:
                outf.write(response.content)
            f = open('outputfilewithc.json',) 
            data = json.load(f)
            for dt in data['statuses']:
                print(dt)

# %%
# name = 'Bhuvan_Bam'
# limit = 1000
# tmp = 0
# err = 0
# errlimit = 500
# #func1(tmp)
# func2(name,limit,tmp,errlimit)

# %%
sss = str(2)
print("new page")
headers = {
            'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
        }
str1 = "https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=Bhuvan_Bam&count=200&page=" + str(sss)
response = requests.get(str1,headers=headers)
with open('ids.json', 'wb') as outf:
    outf.write(response.content)
ff = open('ids.json') 
data1 = json.load(ff)
for x in data1:    
    idd = str(x['id_str'])
    print(idd)
# Out:
# new page
# 1246071494813208582
# 1245924796736499713
# 1245921716787806209
# 1245921487317417988
# 1245920671143563265
# 1245919818965864453
# 1245919606788648962
# 1245394904856973318
# 1245392280669671424
# 1245376985339060224
# 1245090804751683587
# 1245002276910944263
# 1244967905814429699
# 1244966880101588992
# 1244655933273202688
# 1244653842173591552
# 1244470351741894659
# 1244467040108154882
# 1244466263465717762
# 1244104425313951744
# 1243910716823752704
# 1243512890872782856
# 1243434101396221952
# 1243433461123133445
# 1243220524592795649
# 1243216232100159488
# 1243214094649323520
# 1243180935215894529
# 1243169879831638016
# 1242858991442526208
# 1242857009579315201
# 1242821202986450944
# 1242468786080342018
# 1242465661617500161
# 1242430798889811980
# 1242387314518573056
# 1242133674591522816
# 1242132564929736705
# 1242131132218363904
# 1242131129781506048
# 1241751549690306561
# 1241747359018541056
# 1241706455704600577
# 1241700362609782785
# ...

# %%
idd = str('55520326729216000')
headers = {
            'Authorization': 'bearer AAAAAAAAAAAAAAAAAAAAAEZxEwEAAAAAif9iFykj40qr35%2Fr001wdErYDIs%3DaK89PszEgjFkTWN6DbPr05pgsVTu9LPA9WqOuW1DUT6jLsbKZI',
            }
params = (
                ('id', idd),
                ('stringify_ids', 'true')
            )
str1 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + str(idd) + '&count=100'
response = requests.get(str1,headers=headers, params=params)
with open('outputfilewithc.json', 'wb') as outf:
    outf.write(response.content)

# %%
ff = open('outputfilewithc.json') 
data1 = json.load(ff)

# %%
# NAME = 'names.txt'

# def retrieve_last_seen_id(file_name):
#     f_read = open(file_name, 'r')
#     last_seen_id = f_read.readlines()
#     f_read.close()
#     return last_seen_id
# names = retrieve_last_seen_id(NAME)
# for line in names:
#     print(line.strip())
for x in data1['statuses']:
    print(x['id'])
