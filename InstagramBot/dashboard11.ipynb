# %%
# import pyrebase
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from google.cloud import firestore
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import pandas as pd 
from firebase_admin import auth
import json
from json import JSONEncoder
import datetime
# from datetime import datetime
from dateutil.relativedelta import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#DUMP CODE
# config = {
#     "apiKey" : "AIzaSyBY1u9QtTICySrWl2Ssh2od3Zt-vqHuXlw" ,
#     "authDomain": "testing3-a62d0.firebaseapp.com",
#   "databaseURL": "https://testing3-a62d0.firebaseio.com" ,
#   "storageBucket": "testing3-a62d0.appspot.com",
#     "appId": "1:270631454926:android:eda0bd3d5d556e92bd689f",
#     "serviceAccount": "s.json"
# }
# firebase = pyrebase.initialize_app(config)
# auth = firebase.auth()
# user = auth.sign_in_with_email_and_password("sapoorv075@gmail.com","abcdef")
# user
# auth.get_account_info(user['idToken'])
# db = firebase.database()
# users = db.child("Request").get()
# liss = []
# db = firestore.client()
# emp_ref = db.collection('User')
# docs = emp_ref.stream()
# for doc in docs:
#     liss.append(doc.to_dict())
# for i in  range(len(liss)):
#     print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
#     for k in liss[0].keys():
#         try:
#             print(str(k) + " - " +  str(liss[i][k])) 
#         except:
#             print(str(k) + "  - error")
# liss[0].keys()
# Iterate through all users. This will still retrieve users in batches,
# buffering no more than 1000 users in memory at a time.
# for user in auth.list_users().iterate_all():
#     print('User: ' + str(user.uid))

# %%
#DUMP CODE
# # jsonStr = json.dumps(x2.user_metadata.__dict__)
# Dictt = eval(jsonStr) 
# print(Dictt._creat 
# jsonStr
# type(x2.user_metadata._creation_timestamp)
# # print(auth.UserMetadata())
# readable = datetime.datetime.fromtimestamp(1588679131).isoformat()
# print(readable)
# x1 = auth.get_users([auth.EmailIdentifier('sapoorv075@gmail.com')])
# x2 = auth.get_user("1hFL9nsxcMefMX0WqNOXuGDLGPQ2")
# for usr in x1.users:
#     print(usr.user_metadata)
#     jsonStr = json.dumps(usr.__dict__)
# date_time_str = '2018-06-29'
# date_time_obj = datetime.strptime(date_time_str, '%Y-%m-%d')
# for idx in df.index:
#     df["creation_timestamp"][idx] = df["creation_timestamp"][idx][:-9]
#     df["_last_refresh_timestamp"][idx] = df["_last_refresh_timestamp"][idx][:-9]
#     df["_last_sign_in_timestamp"][idx] = df["_last_sign_in_timestamp"][idx][:-9]
# year = 2019
# month = 9
# yearend = 2019
# monthend = 10
# for i in range(10):
#     month+=1
#     monthend+=1
#     if month>12:
#         month %=12
#         year+=1
#     if monthend>12:
#         monthend%=12
#         yearend+=1
#     if month<10:
#         start = str(year) + "-0" + str(month) + "-01"
#     else:
#         start = str(year) + "-" + str(month) + "-01"
#     if monthend<10:
#         end = str(yearend) + "-0" + str(monthend) + "-01"
#     else:
#         end = str(yearend) + "-" + str(monthend) + "-01"
#     print("between " + start + " " + end)
#     cnt = 0
#     for idx in df.index:
#         if df["creation_timestamp"][idx] >= start and df["creation_timestamp"][idx] < end:
#             cnt+=1
#     print(cnt)

# %%
cred = credentials.Certificate('s6.json')
app = firebase_admin.initialize_app(cred)

# %%
# Start listing users from the beginning, 1000 at a time.
liss = []
page = auth.list_users()
while page:
    for user in page.users:
#         print('User: ' + str(user.uid))
        x2 = auth.get_user(str(user.uid))
#         print(x2.user_metadata._creation_timestamp)
        a = x2.user_metadata._creation_timestamp//1000
        b = x2.user_metadata._last_refresh_timestamp//1000
        c = x2.user_metadata._last_sign_in_timestamp//1000
        liss.append([user.uid,datetime.datetime.fromtimestamp(a).isoformat(),
                     datetime.datetime.fromtimestamp(b).isoformat(),
                     datetime.datetime.fromtimestamp(c).isoformat()])
    page = page.get_next_page()
df = pd.DataFrame(liss,columns=["uid","creation_timestamp","_last_refresh_timestamp","_last_sign_in_timestamp"])
from datetime import datetime
for idx in df.index:
    df["creation_timestamp"][idx] = datetime.strptime(df["creation_timestamp"][idx], "%Y-%m-%dT%H:%M:%S")
    df["creation_timestamp"][idx] = df["creation_timestamp"][idx].date()
    df["_last_refresh_timestamp"][idx] = datetime.strptime(df["_last_refresh_timestamp"][idx], "%Y-%m-%dT%H:%M:%S")
    df["_last_refresh_timestamp"][idx] = df["_last_refresh_timestamp"][idx].date()
    df["_last_sign_in_timestamp"][idx] = datetime.strptime(df["_last_sign_in_timestamp"][idx], "%Y-%m-%dT%H:%M:%S")
    df["_last_sign_in_timestamp"][idx] = df["_last_sign_in_timestamp"][idx].date()

# %%
df
# Out:
#                              uid creation_timestamp _last_refresh_timestamp  \
# 0   1hFL9nsxcMefMX0WqNOXuGDLGPQ2         2020-05-05              2020-06-05
# 1   58402sNIt1V4YvKkrTkIc4lY5Rb2         2019-11-07              2020-02-14
# 2   6wnLdTx2nabioHsjfDShLcqlYVw1         2019-11-07              2019-11-11
# 3   7JmSSZ6weWaUrFAIlbMAdJVdivz1         2020-01-14              2020-07-02
# 4   AQaPmv1HdbclxWNbJbQo8w71SN93         2020-03-04              2020-05-26
# 5   FLi4XnQXQXbBrI2rBOAtEzAxMh52         2019-11-07              2019-11-07
# 6   GX306j9hwTfWqUW4bQsIAhjWTS83         2020-06-01              2020-06-02
# 7   H3YBwoL2xac2pML9GWeRYeJvZpR2         2019-06-29              2019-06-29
# 8   WoiYXO5tGRPbnhHxsHy6BcOGaif2         2020-05-06              2020-07-10
# 9   a3CARC5VFyMW3n9YEvvLV6ZutIY2         2020-04-17              2020-05-16
# 10  cDDGUpw2gXMLPdGjFAlslZoTnqt1         2020-04-04              2020-04-04
# 11  e4PYAFVtSTetvIPEC3v3Y8JBwCe2         2019-06-28              2019-07-12
# 12  iz0Osqw1auO0Z8cvnXQUTdieX1t2         2019-07-13              2019-07-13
# 13  noseIsGhmwTx8ZXq6Bajhpvzbdw1         2020-06-27              2020-07-13
# 14  oddeS8Xa1chDdm9gspJlbluLapu2         2019-06-30              2019-06-30
# 15  qb6MUDTN7af1r6y8qKvuWJ3AUG73         2020-05-22              2020-05-22
# 16  rwnl3RS2dNNAgvua5X0NIGibEm82         2020-07-02              2020-07-04
# 17  y8OmlIiKElYLaobkLpgSoWy0h0h2         2020-01-22              2020-05-06
#
#    _last_sign_in_timestamp
# 0               2020-06-05
# 1               2020-02-12
# 2               2019-11-11
# 3               2020-06-30
# 4               2020-05-26
# 5               2019-11-07
# 6               2020-06-01
# 7               2019-06-29
# 8               2020-07-10
# 9               2020-05-16
# 10              2020-04-04
# 11              2019-07-12
# 12              2019-07-13
# 13              2020-07-10
# 14              2019-06-30
# 15              2020-05-22
# 16              2020-07-04
# 17              2020-05-06

# %%
##FEMALES
liss = []
db = firestore.client()
emp_ref = db.collection('User')
docs = emp_ref.stream()
for doc in docs:
    liss.append(doc.to_dict())
    cnt = 0
for i in  range(len(liss)):
    if(liss[i]["Gender"]=="Female"):
        cnt+=1
print(cnt)
# Out:
# 1

# %%
#MONTHWISE
from datetime import date, timedelta
start_date = date(2019, 9, 1)
end_date = date(2019, 10, 1)
delta = timedelta(days=1)
# use_date+relativedelta(months=+1)
# while start_date <= end_date:
#     print (start_date.strftime("%Y-%m-%d"))
#     start_date += relativedelta(months=+1)
for i in range(10):
    print("between" + str(start_date) + " " + str(end_date))
    cnt = 0
    for idx in df.index:
        if df["creation_timestamp"][idx] >= start_date and df["creation_timestamp"][idx] < end_date:
            cnt+=1
    start_date += relativedelta(months=+1)
    end_date += relativedelta(months=+1)
    print(cnt)
# Out:
# between2019-09-01 2019-10-01
# 0
# between2019-10-01 2019-11-01
# 0
# between2019-11-01 2019-12-01
# 3
# between2019-12-01 2020-01-01
# 0
# between2020-01-01 2020-02-01
# 2
# between2020-02-01 2020-03-01
# 0
# between2020-03-01 2020-04-01
# 1
# between2020-04-01 2020-05-01
# 2
# between2020-05-01 2020-06-01
# 3
# between2020-06-01 2020-07-01
# 2

# %%
#### DAYWISE
final_date = date(2020,7,1)
start_date = date(2019, 9, 1)
end_date = date(2019, 9, 2)
inn = (int)((final_date-start_date)/(date(2019,1,2)-date(2019,1,1)))
from datetime import date, timedelta
delta = timedelta(days=1)
# use_date+relativedelta(months=+1)
# while start_date <= end_date:
#     print (start_date.strftime("%Y-%m-%d"))
#     start_date += relativedelta(months=+1)
for i in range(inn):
    cnt = 0
    for idx in df.index:
        if df["creation_timestamp"][idx] >= start_date and df["creation_timestamp"][idx] < end_date:
            cnt+=1
    if(cnt>0):
        print("between " + str(start_date) + " " + str(end_date))
        print(cnt)
    start_date += delta
    end_date += delta
# Out:
# between 2019-11-07 2019-11-08
# 3
# between 2020-01-14 2020-01-15
# 1
# between 2020-01-22 2020-01-23
# 1
# between 2020-03-04 2020-03-05
# 1
# between 2020-04-04 2020-04-05
# 1
# between 2020-04-17 2020-04-18
# 1
# between 2020-05-05 2020-05-06
# 1
# between 2020-05-06 2020-05-07
# 1
# between 2020-05-22 2020-05-23
# 1
# between 2020-06-01 2020-06-02
# 1
# between 2020-06-27 2020-06-28
# 1

# %%
### DAILY ACTIVE
# store = pd.DataFrame(columns=["Date", "Count"])
store = pd.read_csv("store.csv")
df_last = pd.read_csv("data.csv")
inactive = []
for idx in df_last.index:
    df_last["_last_refresh_timestamp"][idx] = datetime.strptime(df_last["_last_refresh_timestamp"][idx], '%Y-%m-%d')
    df_last["_last_refresh_timestamp"][idx] = df_last["_last_refresh_timestamp"][idx].date()
#     df_last["creation_timestamp"][idx] = datetime.strptime(df_last["creation_timestamp"][idx], '%Y-%m-%d')
#     df_last["creation_timestamp"][idx] = df_last["creation_timestamp"][idx].date()
#     df_last["_last_sign_in_timestamp"][idx] = datetime.strptime(df_last["_last_sign_in_timestamp"][idx], '%Y-%m-%d')
#     df_last["_last_sign_in_timestamp"][idx] = df_last["_last_sign_in_timestamp"][idx].date()
cnt = 0
delta = timedelta(days=1)
for idx in df_last.index:
    uid = df_last["uid"][idx]
    prev_date = df_last["_last_refresh_timestamp"][idx]
#     prev_date = df_last.iloc[idx,-1]
    curr =  df[df["uid"] == uid]
    if((int)((curr["_last_refresh_timestamp"]-prev_date)/(delta)) > 0):
        cnt+=1
    if((int)((date.today() - curr["_last_refresh_timestamp"])/(delta)) >= 30):
        inactive.append(curr["uid"])
print(cnt)
tmpdf = pd.DataFrame([[str(date.today()),cnt,inactive]],columns = ["Date", "Count","Inactive"])
store = pd.concat([store, tmpdf],ignore_index=True)
df.to_csv("data.csv")
# Out:
# 0
# /home/apoorv/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/apoorv/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
store
# Out:
#   Unnamed: 0        Date Count  \
# 0        NaN  2020-07-13     0
#
#                                             Inactive
# 0  [[1hFL9nsxcMefMX0WqNOXuGDLGPQ2], [58402sNIt1V4...

# %%
# x1 = date(2019, 1, 1)
# x2 = date(2019,1,31)
# inn = (int)((x2-x1)/(date(2019,1,2)-date(2019,1,1)))
# print(inn)

# %%
# l = []
# for user in auth.list_users().iterate_all():
#     print('User: ' + str(user.uid))
#     l.append(json.dumps(user.__dict__))

# %%
# df = df.drop["creation_timestamp"]
# df = df.drop["_last_sign_in_timestamp"]
# df_last = df_last.drop["creation_timestamp"]
# df_last = df_last.drop["_last_sign_in_timestamp"]
# df_last = pd.read_csv("data.csv")

# %%
# df1 = pd.DataFrame(d1, columns=["A","B"])
# df2 = pd.DataFrame(d2,columns=["A","B"])
# df3 = pd.DataFrame(d3,columns=["B","C"])
# df4 = pd.DataFrame(d4,columns=["A","D","E"])
# d1 = [[1,1],[2,2],[3,3],[4,4]]
# d2 = [[5,5],[6,6],[7,7],[8,8]]
# d3 = [[1,9],[2,10],[5,11],[12,12]]
# d4 = [[1,20,20]]
# df112 = pd.concat([df1,df2,df3,df4], ignore_index=True)
# df112
# for idx in df112.index:    
#     print(df112.iloc[idx,-1])
# for x in store["Inactive"]:
#     print(x)

# %%
# db = firestore.client()
# emp_ref = db.collection('events')
# docs = emp_ref.stream()
# for doc in docs:
#     liss.append(doc.to_dict())
# for i in  range(len(liss)):
#     print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
#     for k in liss[0].keys():
#         try:
#             print(str(k) + " - " +  str(liss[i][k])) 
#         except:
#             print(str(k) + "  - error")
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['Cricket', 'Football']
# onlineEventsPaid - ['3vn0djhy3vlZBh0J3yj3', '5QfACRLQgtgJWQgcjiNu', 'cpKsdjKPxtTUagdhuILM']
# lastExactLoaction - abc
# myReviews - ['5QfACRLQgtgJWQgcjiNu', '2egYWcd4z14m8MXMGil8', '6S2gWMtNryqdULByIky2', 'cpKsdjKPxtTUagdhuILM']
# prevEventsRating - 5.0
# phPlusExpiryDate - 2020-07-22 23:04:05.638
# LastName - Bansal
# TnC - Y
# InstagramID - divyeshbansal
# hostRating - 5.0
# About - This is a test bio.
# Email - divyeshbansal99@gmail.com
# lastKnownLoc - {'longitude': 75.8130964, 'latitude': 26.8345827}
# WorkLocation - Partyherd
# Gender - Male
# OnBoarded - Y
# SocialSkill - Musician (By hobby)
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/image_cropper_1589477031104.jpg?alt=media&token=0139aa6f-accb-4cb3-b30d-b5cc38e0b81e
# pastReviews - ['']
# referrals - ['7JmSSZ6weWaUrFAIlbMAdJVdivz1']
# GcurrentCity - Jaipur
# DateOfBirth - 07-06-1999
# LinkedInUrl -
# Mobile Number - +919784674483
# GsubLocality - Jagatpura
# fToken - cmhzQOFyVIw:APA91bHOYY1Sep2SfsO6wQ5e-6vdnkXoL-s9dksv2ZGucAvUB6BOx3Sl1wvpf97k84B56rEpvjRBPVL-O-oyZj2Tq1INv_6W-3EgRs3R4mPeNmmIfUdtLnbUgFfBENkcH6qw2q0va9JA
# Intent - Trooper
# Profession - Developer
# GcurrentFullLoc - C-454, Block C, Siddharth Nagar, Jagatpura, Jaipur, Rajasthan 302017, India
# MyEvent - {'A': 'A', '6S2gWMtNryqdULByIky2': 'D', '2egYWcd4z14m8MXMGil8': 'D'}
# phPlusSubscribed - Y
# TravelledOversease - No
# platform - Android
# Location - Juhu
# Interests - []
# blockedChatUsers - ['WoiYXO5tGRPbnhHxsHy6BcOGaif2', 'AQaPmv1HdbclxWNbJbQo8w71SN93']
# Name - Divyesh
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['']
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews - ['hello']
# prevEventsRating - 4.7
# phPlusExpiryDate  - error
# LastName  - error
# TnC - Y
# InstagramID -
# hostRating - 4.42578125
# About - Looking to meet new people in Mumbai and building a platform for people to enjoy their weekends.
# Email - singh.vikramjeet92@gmail.com
# lastKnownLoc - {'longitude': 72.836389, 'latitude': 19.1337359}
# WorkLocation - IIT Kanpur
# Gender - Male
# OnBoarded - Y
# SocialSkill - Social-Ice-Breaker
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/img_337.jpg?alt=media&token=07abd8d2-6d5c-4ce8-825c-58243f9e96d8
# pastReviews - []
# referrals  - error
# GcurrentCity - Mumbai
# DateOfBirth - 08-12-2000
# LinkedInUrl -
# Mobile Number - +918853992075
# GsubLocality - Andheri West
# fToken - fquOu7cIC5M:APA91bF7yEhUvkP_2zdnOkihm_kFrjaMayASwrj_8eI9BPSszXXhhospbWuJmZL0fq-DCc0AOxthphSpFbvATl3jlWGxMIBbE6Wx84i5o53_Hfd7SAoPQXmqIqyW6BThME6Kr9bRkxxc
# Intent - Participant
# Profession - Software Engineer
# GcurrentFullLoc - 18, Veera Desai Road, Industrial Area, Andheri West, Mumbai, Maharashtra 400072, India
# MyEvent - {'rjNCthvbJo6mupvfMdsD': 'A', 'F6LHe7BMsWj44luHXWyT': 'D', 'A': 'A'}
# phPlusSubscribed  - error
# TravelledOversease - Yes
# platform - Android
# Location - Marol
# Interests - ['young', 'dumb', 'broke']
# blockedChatUsers  - error
# Name - VJ
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['']
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating - 5.0
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID -
# hostRating - 5.0
# About - I love playing football. I coach and inspire young kids to become better players. Team spirit is important, I love partying over the weekend and bursting the sweat during the weeks. Connect with me if you are interested in some weekend football.
# Email - abc@outlook.com
# lastKnownLoc  - error
# WorkLocation - IIT d
# Gender - Male
# OnBoarded  - error
# SocialSkill - Jolly Person
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/scaled_Screenshot_20191107-213737.jpg?alt=media&token=ce85f69c-8229-42c0-a34b-d8c0375f2906
# pastReviews - ['amazing']
# referrals  - error
# GcurrentCity  - error
# DateOfBirth - 08-05-1979
# LinkedInUrl -
# Mobile Number - +918285223901
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession - Football Coach
# GcurrentFullLoc  - error
# MyEvent - {'A': 'A'}
# phPlusSubscribed  - error
# TravelledOversease - Yes
# platform  - error
# Location - Mumbai
# Interests  - error
# blockedChatUsers  - error
# Name - Rohan Saxena
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['Cricket', 'Football']
# onlineEventsPaid - ['5QfACRLQgtgJWQgcjiNu']
# lastExactLoaction  - error
# myReviews - ['J11UtVlwHOMpqj5j72Xb', 'GPNpQiSZobDjawEiBi0Z', 'cpKsdjKPxtTUagdhuILM', '5QfACRLQgtgJWQgcjiNu']
# prevEventsRating - 3.66425783150702
# phPlusExpiryDate - 2020-09-28 15:18:16.360676
# LastName - Bansal
# TnC - Y
# InstagramID - divyeshbansal
# hostRating - 2.97705078125
# About - This is a test bio. This is a test bio. This is a test bio. This is a test bio.
# Email - abc@gmail.com
# lastKnownLoc - {'longitude': 75.8130609, 'latitude': 26.8347102}
# WorkLocation - Partyherd
# Gender - Male
# OnBoarded - Y
# SocialSkill - Conversationalist
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/image_cropper_1591692532566.jpg?alt=media&token=1a59e52f-9b68-4a7c-9255-58e950b43944
# pastReviews - ['abcedf', 'nice', 'shri', 'abced', 'hehe', 'amazing', 'Amazing', '', 'My Review ', 'grygfdg', 'fgcg', 'fy', 'jdjd\n', 'y']
# referrals - ['qb6MUDTN7af1r6y8qKvuWJ3AUG73']
# GcurrentCity - Jaipur
# DateOfBirth - 07-06-1999
# LinkedInUrl -
# Mobile Number - +918928136419
# GsubLocality - Jagatpura
# fToken - fQMc6EZbD9I:APA91bHhd5OKTzzZlH0SjlJeK7sUw2SxjH3CTew32DcMXbNk65iOhYOZmMe9tuZ0J01OD46rHyusijYIlypRUfe_7gL0G6X8cJ1Koi-fBYTD4egFFUt3hoE0W9nS2J_33JYlCk_YC1XS
# Intent - Trooper
# Profession - Developer
# GcurrentFullLoc - C-454, Block C, Siddharth Nagar, Jagatpura, Jaipur, Rajasthan 302017, India
# MyEvent - {'A': 'A', 'J11UtVlwHOMpqj5j72Xb': 'D', '7zpyWalsn9Q9qHtgnTWA': 'P'}
# phPlusSubscribed - Y
# TravelledOversease - Yes
# platform - Android
# Location - Juhu, Mumbai
# Interests - ['lap rounds', 'football streams']
# blockedChatUsers - []
# Name - Divyesh
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['Football', 'Cricket']
# onlineEventsPaid - ['GPNpQiSZobDjawEiBi0Z']
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating - 5.0
# phPlusExpiryDate - 2020-06-22 12:17:12.759412
# LastName  - error
# TnC - Y
# InstagramID -
# hostRating - 4.75
# About - Test
# Email - shefalimonga1612@gmail.com
# lastKnownLoc - {'longitude': 72.8853232, 'latitude': 19.0993098}
# WorkLocation - ABC
# Gender - Female
# OnBoarded - Y
# SocialSkill - Conversationalist
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/IMG_20200117_114003.jpg?alt=media&token=045e0139-d390-45fe-9518-eda5cd218841
# pastReviews - ['abced', 'amazing', '']
# referrals  - error
# GcurrentCity - Mumbai
# DateOfBirth - 16-01-2000
# LinkedInUrl -
# Mobile Number - +919930150177
# GsubLocality - Saki Naka
# fToken - e-WQ9caVjwE:APA91bHIHpZXwgSGXmP_KU5lFgTm7HyZ3yzSu7yRu96ENT6O3PjV53F-23GPxLH3KhjMZLMKo9pm3XLZ_aUjsZV7T5FcumyZuvZHukUwTeZwV0IAJMib3mzYf6tEt5IWqpD0iZHbhf7a
# Intent - Leader
# Profession - Security Analyst
# GcurrentFullLoc - Lane opposite Orkey mills compound, Mehra Compound Road, Safed Pul, Saki Naka, Mumbai, Maharashtra 400072, India
# MyEvent - {'fHubWvIChyabomIcQ3x4': 'A', '2egYWcd4z14m8MXMGil8': 'P', 'd7pKnwpG19xnzvuDXiAo': 'P', 'A': 'A', '9f5OFGEQQ2PVpISxclN1': 'P'}
# phPlusSubscribed - Y
# TravelledOversease - Yes
# platform - Android
# Location - Mumbai
# Interests - []
# blockedChatUsers - []
# Name - Shefali
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - []
# onlineEventsPaid - []
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC - Y
# InstagramID -
# hostRating  - error
# About -
# Email -
# lastKnownLoc - {'longitude': 79.0827736, 'latitude': 21.1469525}
# WorkLocation -
# Gender -
# OnBoarded - Y
# SocialSkill -
# FacebookID -
# ProfilePicUrl -
# pastReviews  - error
# referrals - []
# GcurrentCity - Nagpur
# DateOfBirth -
# LinkedInUrl -
# Mobile Number - +919022121692
# GsubLocality - Sitabuldi
# fToken - eZGcjr1cqlA:APA91bE_5oHblm2AXLUqoCjigMGevF6uZZ7Xs_u2eTgqn8FqRhvUI0DU0ltia5X9D_BW2LN0iEpg7WGTMbfljK0ettL1f-5rlGj0o5gKKtisTFmwXRR9bUdmBXIeY_zGR-Z5om53qadA
# Intent - Trooper
# Profession -
# GcurrentFullLoc - 140, Sitabuldi, Nagpur, Maharashtra 440012, India
# MyEvent - {'A': 'A'}
# phPlusSubscribed - N
# TravelledOversease -
# platform - Android
# Location -
# Interests - []
# blockedChatUsers - []
# Name -
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['Cricket', 'Football']
# onlineEventsPaid - ['WEnvFQ8LsmKbLFafpBuI']
# lastExactLoaction  - error
# myReviews - []
# prevEventsRating - 3.3
# phPlusExpiryDate  - error
# LastName - Singh
# TnC - Y
# InstagramID - pun_ender
# hostRating  - error
# About - I love coding
# Email - singh.vikramjeet92@gmail.com
# lastKnownLoc - {'longitude': 77.53782, 'latitude': 29.93845}
# WorkLocation - Billdesk
# Gender - Male
# OnBoarded - Y
# SocialSkill - Introvert
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/image_cropper_1588759931219.jpg?alt=media&token=bb86ae25-af16-4b21-8864-d21ce619a32c
# pastReviews  - error
# referrals  - error
# GcurrentCity - Saharanpur
# DateOfBirth - 01-01-2000
# LinkedInUrl -
# Mobile Number - +918830177502
# GsubLocality - Rohit Vihar
# fToken - cSgHDYwtSoeuic7bqaMGE7:APA91bE3yKzayiXqcxi9AupXWO9ZZAYTRHZPmSpoAYzgOBSvRKcepnhNhrtGZY2M9wBbKUfTCnMNPRsys19qo-uX-p2Vhr0RxBFKWxDrneslFbYGq77b7QfVPv4X6Iozcs0NBxtt2jSG
# Intent - Participant
# Profession - software
# GcurrentFullLoc - Saharanpur - Delhi Rd, Rohit Vihar, Saharanpur, Uttar Pradesh 247001, India
# MyEvent - {'A': 'A', 'J11UtVlwHOMpqj5j72Xb': 'P'}
# phPlusSubscribed - N
# TravelledOversease - Yes
# platform - Android
# Location - Andheri
# Interests - ['football', 'cricket', 'pubg']
# blockedChatUsers - []
# Name - Vicky
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['', 'Football', 'Cricket']
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName -
# TnC - Y
# InstagramID -
# hostRating  - error
# About - this is a test
# Email - abc@abc.com
# lastKnownLoc - {'longitude': 72.8852504, 'latitude': 19.0994015}
# WorkLocation - partyherd
# Gender - Male
# OnBoarded - Y
# SocialSkill - Conversationalist
# FacebookID -
# ProfilePicUrl - https://images.unsplash.com/photo-1497316730643-415fac54a2af?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=700&q=80
# pastReviews  - error
# referrals  - error
# GcurrentCity - Mumbai
# DateOfBirth - 01-01-1996
# LinkedInUrl -
# Mobile Number - +919325887800
# GsubLocality - Saki Naka
# fToken - fqXqwRT3qZA:APA91bEDGey3py8cCBUa2gLasSY8ViSwMArTfw1rwa7uKYW_zAEmvGpNF-TwroxcDdC286wfnwL_04PQhBykg_WWOpzkmLhJMJl5Li17aGD7LdxJUo_4cekrVW9dmi6UIPTgfvKpQOss
# Intent - Participant
# Profession - test
# GcurrentFullLoc - Lane opposite Orkey mills compound, Mehra Compound Road, Safed Pul, Saki Naka, Mumbai, Maharashtra 400072, India
# MyEvent - {'A': 'A'}
# phPlusSubscribed  - error
# TravelledOversease - None
# platform - Android
# Location - Mumbai
# Interests - []
# blockedChatUsers  - error
# Name - hbdnd
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['Cricket']
# onlineEventsPaid - ['WEnvFQ8LsmKbLFafpBuI']
# lastExactLoaction  - error
# myReviews - ['WEnvFQ8LsmKbLFafpBuI']
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC - Y
# InstagramID -
# hostRating  - error
# About - About mejsjdjdjj
# Email -
# lastKnownLoc - {'latitude': 29.9385439, 'longitude': 77.5388335}
# WorkLocation - Company Name
# Gender -
# OnBoarded - Y
# SocialSkill - Conversationalist
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/image_cropper_1594294304441.jpg?alt=media&token=8e75be0d-e9a2-492e-93ec-8fe97faad85d
# pastReviews  - error
# referrals - []
# GcurrentCity - Saharanpur
# DateOfBirth - 28-02-2000
# LinkedInUrl -
# Mobile Number - +917037251245
# GsubLocality - Vasant Vihar
# fToken - cWPOE01wRBO47X3rUWzsHJ:APA91bGNrd1efvtfTQ5yxucvZRvk7mDM3Mh3lw3ZS0TvjKkeD_-vNnS0G2nDSHTp20NqlKurtwpStFOH3o2jnuyQ50SvSA8IPYfo3OxxQfSqM4llvLaPObpllpsGInYd2WEio1lirQZF
# Intent - Participant
# Profession - Student
# GcurrentFullLoc - Sardar Patel Marg, Shiv Vihar Colony, Vasant Vihar, Saharanpur, Uttar Pradesh 247001, India
# MyEvent - {'A': 'A'}
# phPlusSubscribed - N
# TravelledOversease -
# platform - Android
# Location -
# Interests - []
# blockedChatUsers - []
# Name - Sujit Jaiwaliya
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - []
# onlineEventsPaid - []
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate - 2020-05-29 16:16:21.517733
# LastName  - error
# TnC - Y
# InstagramID -
# hostRating  - error
# About -
# Email -
# lastKnownLoc - {'longitude': 72.885307, 'latitude': 19.0993063}
# WorkLocation -
# Gender -
# OnBoarded - Y
# SocialSkill -
# FacebookID -
# ProfilePicUrl -
# pastReviews  - error
# referrals - []
# GcurrentCity - Mumbai
# DateOfBirth -
# LinkedInUrl -
# Mobile Number - +917755057889
# GsubLocality - Saki Naka
# fToken - dHRIA5aSfo4:APA91bGiswbZrKyCWS60DX6BguTJc_YHNvxF7S2L7pJ0jJSVgAGswRBVU5854-S8M8ITGTvFTZ6zOynXBuXWPyJxvFflymYuxhNQ8BL8FH0JP025VNjU6jpJ16F-Pa6UESp0XRXV-zQS
# Intent - Participant
# Profession -
# GcurrentFullLoc - Lane opposite Orkey mills compound, Mehra Compound Road, Safed Pul, Saki Naka, Mumbai, Maharashtra 400072, India
# MyEvent - {'A': 'A'}
# phPlusSubscribed - Y
# TravelledOversease -
# platform - Android
# Location -
# Interests - ['chill', 'pubg']
# blockedChatUsers  - error
# Name -
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes - ['', 'Cricket', 'Football']
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating - 1.4
# phPlusExpiryDate  - error
# LastName  - error
# TnC - Y
# InstagramID -
# hostRating - 4.4
# About - Here to make your app experience better.
# Email - ap.aayushpal@gmail.com
# lastKnownLoc - {'longitude': 75.8131042, 'latitude': 26.83472}
# WorkLocation - Partyherd Team
# Gender - Male
# OnBoarded - Y
# SocialSkill - Conversationalist
# FacebookID -
# ProfilePicUrl - https://firebasestorage.googleapis.com/v0/b/testing3-a62d0.appspot.com/o/IMG-20200203-WA0016.jpg?alt=media&token=347a04ea-bafb-498b-94e9-14fcc13966b2
# pastReviews  - error
# referrals  - error
# GcurrentCity - Jaipur
# DateOfBirth - 01-01-1992
# LinkedInUrl -
# Mobile Number - +918369176490
# GsubLocality - Jagatpura
# fToken - eiGSDAU0_Q4:APA91bEmg_jEQOkL8kbErcUcUqJB4-RpEpG-xFPr0D-ITY5N_hzeUfcO9pG8eavaJz_m-bMlnVCyN96ba4DgslhNiSq7HBtssuJNSdb3jF-kTx7IktwQSgMBFXzrgwveN7VredylxgkQ
# Intent - Trooper
# Profession - Mobile Developer
# GcurrentFullLoc - C-454, Block C, Siddharth Nagar, Jagatpura, Jaipur, Rajasthan 302017, India
# MyEvent - {'2egYWcd4z14m8MXMGil8': 'P', 't8fvBI4OO3vC2DUXi8lK': 'P', 'A': 'A', '7zpyWalsn9Q9qHtgnTWA': 'P'}
# phPlusSubscribed  - error
# TravelledOversease - No
# platform - Android
# Location - Thane
# Interests - ['football', 'cycling', 'coffee', 'book reading', 'parties']
# blockedChatUsers  - error
# Name - Aayush
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# subscribedGroupTypes  - error
# onlineEventsPaid  - error
# lastExactLoaction  - error
# myReviews  - error
# prevEventsRating  - error
# phPlusExpiryDate  - error
# LastName  - error
# TnC  - error
# InstagramID  - error
# hostRating  - error
# About  - error
# Email  - error
# lastKnownLoc  - error
# WorkLocation  - error
# Gender  - error
# OnBoarded  - error
# SocialSkill  - error
# FacebookID  - error
# ProfilePicUrl  - error
# pastReviews  - error
# referrals  - error
# GcurrentCity  - error
# DateOfBirth  - error
# LinkedInUrl  - error
# Mobile Number  - error
# GsubLocality  - error
# fToken  - error
# Intent  - error
# Profession  - error
# GcurrentFullLoc  - error
# MyEvent  - error
# phPlusSubscribed  - error
# TravelledOversease  - error
# platform  - error
# Location  - error
# Interests  - error
# blockedChatUsers  - error
# Name  - error

# %%
x = firebase_admin.firestore.client(app=app)
x2 = x.collection("events")

# %%
docs = x2.stream()
for doc in docs:
    if(doc.exists()==True):
        print("True")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-209b46236c39> in <module>
#       1 docs = x2.stream()
#       2 for doc in docs:
# ----> 3     if(doc.exists()==True):
#       4         print("True")
#
# TypeError: 'bool' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-b73ad5a29351> in <module>
#       1 for doc in docs:
# ----> 2     print(doc.exists())
#
# TypeError: 'bool' object is not callable

# %%
print(cnt)
# Out:
# 0
